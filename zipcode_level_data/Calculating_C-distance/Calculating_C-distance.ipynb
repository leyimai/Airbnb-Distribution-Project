# %% [markdown]
# # Testing calculating methods

# %%
# !pip install haversine
# Out:
# Requirement already satisfied: haversine in d:\anaconda3\lib\site-packages (2.1.2)

# %%
import pandas as pd
import numpy as np
from haversine import haversine, Unit

# %% [markdown]
# We can test the method through calculating the distance between timesquare and whitehouse

# %%
timesquare = (40.75773, -73.985708) # (lat, lon)
bostoncommon = (42.355, -71.0656)
whitehouse = (38.897957, -77.036560)
ny_cityhall = (40.712772, -74.006058)
bos_cityhall = (42.3562, -71.0548)
dc_cityhall = (38.895278, -77.017778)
haversine(timesquare, whitehouse)
# Out:
# 332.58751900742413

# %% [markdown]
# # Calculating C-Distance using zipcode

# %%
ny = pd.read_csv('ny_data_by_zipcode.csv')
bos = pd.read_csv('bos_data_by_zipcode.csv')
dc = pd.read_csv('dc_data_by_zipcode.csv')
centroid = pd.read_csv('gaz2016zcta5centroid.csv')

# %%
centroid = centroid.rename(columns={'intptlat':'lat', 'intptlong':'long' ,'zcta5':'zipcode'})

# %%
def get_distance(zipcode, center):
    row = centroid[centroid['zipcode'] == zipcode]
    coordinate = (row.iloc[0,0],row.iloc[0,1])
    distance = haversine(coordinate, center)
    return round(distance,3)

# %%
get_distance(10025, timesquare)
# Out:
# 4.82

# %% [markdown]
# # NYC C-distance

# %%
ny['C-distance_ts'] = ny.apply(lambda x: get_distance(x['zipcode'], timesquare), axis=1)
ny['C-distance_ch'] = ny.apply(lambda x: get_distance(x['zipcode'], ny_cityhall), axis=1)
ny.to_csv('ny_data_by_zipcode_with_C-distance.csv')
ny.head()
# Out:
#    Unnamed: 0  zipcode  num_of_airbnb  num_of_beds   avg_price  total_reviews  \
# 0           0     7093              1          3.0  288.000000             77
# 1           1    10001            513        466.0  250.085770          11336
# 2           2    10002           1213       1377.0  185.379225          33405
# 3           3    10003           1032       1156.0  238.921512          22102
# 4           4    10004             68         62.0  201.426471            853
#
#    avg_location_review_score  avg_review_score  num_of_bus  num_of_sub  ...  \
# 0                   9.000000          9.000000         NaN         NaN  ...
# 1                   9.754144          8.950276        17.0         5.0  ...
# 2                   9.690816          9.318367        33.0         6.0  ...
# 3                   9.908616          9.352480        18.0         6.0  ...
# 4                   9.925000          9.450000         3.0         3.0  ...
#
#    $25,000-$34,999  $35,000-$49,999  $50,000-$64,999  $65,000-$74,999  \
# 0             13.1              8.7             13.9             18.2
# 1              9.3              5.1              9.2              8.5
# 2               14              8.8               10             14.2
# 3                7              4.9              6.4               13
# 4              1.7              6.5              5.1              7.1
#
#    $75,000-$99,999  $100,000_or_more  median_household_income  \
# 0             10.4              42.5                    47611
# 1              9.8              27.5                    86801
# 2              7.1              31.3                    33726
# 3             11.3              30.7                    98151
# 4             14.8                27                   119691
#
#    mean_household_income  C-distance_ts  C-distance_ch
# 0                  68956          4.012          8.388
# 1                 158183          1.247          4.276
# 2                  61946          4.665          1.706
# 3                 161692          2.895          2.552
# 4                 177262          8.132          2.848
#
# [5 rows x 38 columns]

# %% [markdown]
# # Boston C-distance

# %%
bos['C-distance_bc'] = bos.apply(lambda x: get_distance(x['zipcode'], bostoncommon), axis=1)
bos['C-distance_ch'] = bos.apply(lambda x: get_distance(x['zipcode'], bos_cityhall), axis=1)
bos.to_csv('bos_data_by_zipcode_with_C-distance.csv')
bos.head()
# Out:
#    Unnamed: 0  zipcode  num_of_airbnb  num_of_beds   avg_price  total_reviews  \
# 0           0     2026              1          1.0   50.000000              1
# 1           1     2108            111        154.0  256.279279           6217
# 2           2     2109             88        121.0  240.136364           4185
# 3           3     2110             39         37.0  249.000000           1184
# 4           4     2111            213        234.0  255.187793           5426
#
#    avg_location_review_score  avg_review_score  num_of_bus  num_of_sub  ...  \
# 0                   4.000000          8.000000        31.0         NaN  ...
# 1                   9.905660          9.235849        24.0         6.0  ...
# 2                   9.985075          9.179104        13.0         1.0  ...
# 3                   9.514286          9.028571        23.0         NaN  ...
# 4                   9.641618          8.936416         8.0         6.0  ...
#
#    $25,000-$34,999  $35,000-$49,999  $50,000-$64,999  $65,000-$74,999  \
# 0              6.9              5.8             10.0             15.7
# 1              3.6              4.5              8.4              6.8
# 2              3.8              3.6              7.8              9.8
# 3              7.0              6.2              7.7             12.1
# 4             10.7              6.7              6.8             12.9
#
#    $75,000-$99,999  $100,000_or_more  median_household_income  \
# 0             13.3              39.0                    83438
# 1             12.9              28.1                   103973
# 2              8.9              26.5                   111313
# 3              8.9              28.7                   128210
# 4              6.2              25.9                    51480
#
#    mean_household_income  C-distance_bc  C-distance_ch
# 0                 109399         15.240         15.903
# 1                 176335          0.312          0.848
# 2                 166627          1.825          1.255
# 3                 240767          1.652          0.859
# 4                 121824          0.732          0.723
#
# [5 rows x 38 columns]

# %% [markdown]
# # Washington DC C-distance

# %%
dc['C-distance_wh'] = dc.apply(lambda x: get_distance(x['zipcode'], whitehouse), axis=1)
dc['C-distance_ch'] = dc.apply(lambda x: get_distance(x['zipcode'], dc_cityhall), axis=1)
dc.to_csv('dc_data_by_zipcode_with_C-distance.csv')
dc.head()
# Out:
#    Unnamed: 0  zipcode  num_of_airbnb  num_of_beds   avg_price  total_reviews  \
# 0           0     2939              1          1.0  100.000000              1
# 1           1    20001           1290       1947.0  210.800775          62223
# 2           2    20002           1593       2359.0  196.335844          73416
# 3           3    20003            742       1095.0  219.907008          35561
# 4           4    20004             18         24.0  482.833333            103
#
#    avg_location_review_score  avg_review_score  num_of_bus  num_of_sub  ...  \
# 0                  10.000000         10.000000         NaN         NaN  ...
# 1                   9.695446          9.477230       177.0         4.0  ...
# 2                   9.554883          9.596212       258.0         2.0  ...
# 3                   9.812601          9.623586        89.0         5.0  ...
# 4                  10.000000          9.666667        40.0         2.0  ...
#
#    $25,000-$34,999  $35,000-$49,999  $50,000-$64,999  $65,000-$74,999  \
# 0              NaN              NaN              NaN              NaN
# 1              7.5              5.5              7.1             10.1
# 2              6.9                6              9.2               12
# 3              3.7              3.5                6             12.2
# 4              0.6              2.2              5.9              9.2
#
#    $75,000-$99,999  $100,000_or_more  median_household_income  \
# 0              NaN               NaN                      NaN
# 1              9.3              26.5                    85976
# 2             11.5              32.7                    74303
# 3             11.6              29.8                   112083
# 4              7.8              22.9                   135859
#
#    mean_household_income  C-distance_wh  C-distance_ch
# 0                    NaN        625.272        626.236
# 1                 106670          2.134          1.676
# 2                  98792          4.649          3.150
# 3                 140336          4.336          2.762
# 4                 173373          0.766          0.941
#
# [5 rows x 38 columns]
